# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
import pandas as pd
import requests
import csv
import numpy as np 

df = pd.read_csv('https://raw.githubusercontent.com/Imme21/WordCloud/main/StockData3.csv', usecols=fields)
text = df['Stock'].values
#tick = df['Tickers'].values 


wordcloud = WordCloud(background_color = 'white',
               stopwords = ['Date','Stock', 'Tickers', 'Open',
                            'Close', 'High', 'Low', 'IV', 'under',
                            'over', 'price', 'change', '%', 'null']).generate(str(text))

plt.imshow(wordcloud) 
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-94bab007d4e0> in <module>
#       6 import numpy as np
#       7
# ----> 8 df = pd.read_csv('https://raw.githubusercontent.com/Imme21/WordCloud/main/StockData3.csv', usecols=fields)
#       9 text = df['Stock'].values
#      10 #tick = df['Tickers'].values
#
# NameError: name 'fields' is not defined

# %%
fields = ['Stock']
df = pd.read_csv('https://raw.githubusercontent.com/Imme21/WordCloud/main/StockData3.csv', usecols=fields)

text = df['Stock'].values

#rcParams['figure.figsize'] = 20, 5
wordcloud = WordCloud().generate(str(text))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
#from matplotlib import pyplot as plt
#import pandas as pd
#import numpy as np

from pylab import rcParams
#rcParams['figure.figsize'] = 20, 5

#plt.style.use('bmh')
#df = pd.read_csv('https://raw.githubusercontent.com/Imme21/WordCloud/main/StockData2.csv')

#x = df.Stock
#y = df.Tickers


#plt.xlabel('Stock', fontsize=18)
#plt.ylabel('Tickers', fontsize=16)
#plt.bar(x, y)



#plt.show()

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

plt.style.use('bmh')
df = pd.read_csv('https://raw.githubusercontent.com/Imme21/WordCloud/main/StockData3.csv')

df.dropna(inplace = True)

print(df.shape)
x = df['Stock']
y = df.Tickers


plt.xlabel('Stock', fontsize=18)
plt.ylabel('Tickers', fontsize=16)
plt.scatter(x, y)



plt.show()
# Out:
# (56, 9)

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

plt.style.use('bmh')
df = pd.read_csv('https://raw.githubusercontent.com/Imme21/WordCloud/main/StockData2.csv')

rcParams['figure.figsize'] = 20, 10
df.dropna(inplace = True)

x = df['Stock']
y = df['price change %'].str.replace('%', '').astype(float)#.abs()

y_indexes = np.arange(len(y))

plt.xlabel('Stock', fontsize=18)
plt.ylabel('Percent Change', fontsize=16)
plt.scatter(x,y)
plt.ylim(ymax = 20, ymin = -20)


plt.show()

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

plt.style.use('bmh')
df = pd.read_csv('https://raw.githubusercontent.com/Imme21/WordCloud/main/StockData2.csv')

plt.rcParams['figure.figsize'] = 20, 10
df.dropna(inplace = True)

x = df['Stock']
y = df['price change %'].str.replace('%', '').astype(float).abs()

y_indexes = np.arange(len(y))

plt.xlabel('Stock', fontsize=18)
plt.ylabel('Percent Change', fontsize=16)
plt.scatter(x,y)
plt.ylim(ymax = 15, ymin = 0)


plt.show()

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

plt.style.use('bmh')
df = pd.read_csv('https://raw.githubusercontent.com/Imme21/WordCloud/main/StockData2.csv')

rcParams['figure.figsize'] = 20, 10
df.dropna(inplace = True)

x = df['Stock']
y = df['price change %'].str.replace('%', '').astype(float).abs()

y_indexes = np.arange(len(y))

plt.xlabel('Stock', fontsize=18)
plt.ylabel('Percent Change', fontsize=16)
plt.bar(x,y)
plt.ylim(ymax = 15, ymin = 0)


plt.show()

# %%
import csv

with open('C:/Users/immek/Desktop/StockData2.csv') as input, open('C:/Users/immek/Desktop/StockData3.csv', 'w', newline='') as output:
     writer = csv.writer(output)
     for row in csv.reader(input):
         if any(field.strip() for field in row):
             writer.writerow(row)

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

plt.style.use('bmh')
df = pd.read_csv('C:/Users/immek/Desktop/StockData3.csv')

rcParams['figure.figsize'] = 20, 10
df.dropna(inplace = True)

x = df['Stock']
y = df['price change %'].str.replace('%', '').astype(float)#.abs()

y_indexes = np.arange(len(y))

plt.xlabel('Stock', fontsize=18)
plt.ylabel('Percent Change', fontsize=16)
plt.scatter(x,y)
plt.ylim(ymax = 20, ymin = -20)


plt.show()

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

plt.style.use('bmh')
df = pd.read_csv('C:/Users/immek/Desktop/StockData3.csv')

rcParams['figure.figsize'] = 20, 10
df.dropna(inplace = True)

x = df['Stock']
y = df['price change %'].str.replace('%', '').astype(float).abs()

y_indexes = np.arange(len(y))

plt.xlabel('Stock', fontsize=18)
plt.ylabel('Percent Change', fontsize=16)
plt.bar(x,y)
plt.ylim(ymax = 40, ymin = 0)


plt.show()
